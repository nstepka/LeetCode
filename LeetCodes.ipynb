# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Step 1: Create a simple dataset
# X - feature (independent variable), y - target (dependent variable)
X = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))
y = np.array([5, 20, 14, 32, 22, 38])

# Step 2: Already split into X (features) and y (target)

# Step 3: Create a linear regression model
model = LinearRegression()

# Step 4: Train the model
model.fit(X, y)

# Step 5: Make predictions
y_pred = model.predict(X)

# Coefficients and model evaluation
slope = model.coef_
intercept = model.intercept_
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Step 6: Visualization
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.title('Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.show()


# Define two matrices
matrix1 = np.array([[1, 2], [3, 4]])
matrix2 = np.array([[5, 6], [7, 8]])

# Add the matrices together
result = matrix1 + matrix2

# Print the result
print(result)

(slope, intercept, mse, r2)
# Out:
# (array([0.54]), 5.633333333333329, 33.75555555555555, 0.7158756137479542)

# %%
if __name__ == '__main__':
    N = int(input())
    list = []
    
    for _ in range(N):
        line = input().split()
        command = line[0]
        
        if command == "insert":
            index, element = int(line[1]), int(line[2])
            list.insert(index, element)
        elif command == "print":
            print(list)
        elif command == "remove":
            element = int(line[1])
            list.remove(element)
        elif command == "append":
            element = int(line[1])
            list.append(element)
        elif command == "sort":
            list.sort()
        elif command == "pop":
            list.pop()
        elif command == "reverse":
            list.reverse()

# %%
if __name__ == '__main__':
    student_marks = []
    for _ in range(int(input())):
        name = input()
        score = float(input())
        student_marks.append((name, score))

    # Sort the student marks by score
    sorted_marks = sorted(student_marks, key=lambda x: x[1])

    # Extract the second lowest score
    second_lowest_score = sorted(set(mark for name, mark in sorted_marks))[1]

    # Get all students with the second lowest score and sort their names
    second_lowest_students = sorted(name for name, mark in sorted_marks if mark == second_lowest_score)

    # Print each student's name on a new line
    for student in second_lowest_students:
        print(student)

# %% [markdown]
# if __name__ == '__main__':
#     n = int(input())
#     arr = list(map(int, input().split()))
#     arr = set(sorted(arr, reverse=True))
#     second_highest = list(arr)[1]
#     print(second_highest)

# %%
(Select u.name as results 
from MovieRating as m, Users as u 
where u.user_id = m.user_id Group By m.user_id 
Order by count(m.user_id) desc, u.name limit 1)
union all
(Select m.title as results
from MovieRating as r, Movies as m
where m.movie_id = r.movie_id 
and r.created_at like "2020-02-%"
Group By r.movie_id 
Order by avg(r.rating) desc, m.title limit 1);

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
import pandas as pd
from sklearn.datasets import load_iris

# Load the iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Create a decision tree classifier
clf = DecisionTreeClassifier()

# Train the classifier on the training data
clf.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = clf.predict(X_test)

# Evaluate the model
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Load the iris dataset
iris = load_iris()

# Convert iris to a pandas DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target

# Print the DataFrame
print(df)
# Out:
# Accuracy: 0.9555555555555556
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
# Out:
# Accuracy: 0.9555555555555556
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Plot the decision tree
plt.figure(figsize=(10, 8))
plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
plt.show()

# %%
def plusMinus(arr):
    # Initialize counters for positive, negative, and zero elements
    positive_count = 0
    negative_count = 0
    zero_count = 0
    
    # Iterate through the array and count the number of positive, negative, and zero elements
    for num in arr:
        if num > 0:
            positive_count += 1
        elif num < 0:
            negative_count += 1
        else:
            zero_count += 1
    
    # Calculate the fraction of positive, negative, and zero elements
    positive_fraction = positive_count / len(arr)
    negative_fraction = negative_count / len(arr)
    zero_fraction = zero_count / len(arr)
    
    # Print the fractions with 6 decimal places
    print("{:.6f}".format(positive_fraction))
    print("{:.6f}".format(negative_fraction))
    print("{:.6f}".format(zero_fraction)

# %%
from collections import Counter
def solution(A):
    # Count the occurrences of each element in the list
    count = Counter(A)

    # Iterate through the elements and return the one that appears only once
    for element, frequency in count.items():
        if frequency == 1:
            return element

# %%
def count_substring(string, sub_string):
    c = 0
    a = 0
    while string.find(sub_string, a) != -1:
        a = string.find(sub_string, a) + 1
        c += 1

# %%
class Solution(object):
    def lengthOfLongestSubstring(self, s):
        """
        :type s: str
        :rtype: int
        """
        ##loop through the string
        ##if the character is not in the substring, add it to the substring
        ##if the character is in the substring, remove the substring up to the character
        ##return the length of the longest substring
        substring = ''
        longest = 0
        
        for char in s:
            if char not in substring:
                substring += char
                longest = max(longest, len(substring))
            else:
                cut = substring.index(char)
                substring = substring[cut+1:] + char
        return longest

# %%
def find_unique_integer(arr):
    n = len(arr)
    if n == 1:
        return arr[0]
    
    for i in range(0, n-1, 2):
        if arr[i] != arr[i+1]:
            return arr[i]
    
    return arr[n-1]

# %%
def containsDuplicate(nums):
    """
    :type nums: List[int]
    :rtype: bool
    """
    # Create a set to store the unique elements
    unique_elements = set()
    
    # Iterate through the list of numbers
    for num in nums:
        # If the number is already in the set, return True
        if num in unique_elements:
            return True
        # Otherwise, add the number to the set
        else:
            unique_elements.add(num)
    
    # If no duplicates are found, return False
    return False

# %%
import collections

def isAnagram(s, t):
    """
    :type s: str
    :type t: str
    :rtype: bool
    """
    # If the lengths of the strings are different, they cannot be anagrams
    if len(s) != len(t):
        return False
    
    # Create a dictionary to store the frequency of characters in the first string
    char_count = {}
    
    # Iterate through the first string and count the frequency of each character
    for char in s:
        if char in char_count:
            char_count[char] += 1
        else:
            char_count[char] = 1
    
    # Iterate through the second string and decrement the frequency of each character
    for char in t:
        if char in char_count:
            char_count[char] -= 1
        else:
            return False
    
    # If any character has a non-zero frequency, the strings are not anagrams
    for count in char_count.values():
        if count != 0:
            return False
    
    # If all characters have zero frequency, the strings are anagrams
    return True





def isAnagram(s,t):
    return sorted(s) == sorted(t)

def isAnagram(s,t):
    return collections.Counter(s) == collections.Counter(t)

# %%
def bubble_sort(string):
    # Convert the string to a list of characters
    chars = list(string)
    
    # Get the length of the string
    n = len(chars)
    
    # Perform bubble sort
    for i in range(n):
        for j in range(0, n-i-1):
            # Compare adjacent characters and swap if necessary
            if chars[j] > chars[j+1]:
                chars[j], chars[j+1] = chars[j+1], chars[j]
    
    # Convert the sorted list back to a string
    sorted_string = ''.join(chars)
    
    return sorted_string

# Test the function
string = "hello"
sorted_string = bubble_sort(string)
print(sorted_string)

# %%
def twoSum(nums, target):
    # Create a dictionary to store the complement of each number
    complement_dict = {}
    
    # Iterate through the list of numbers
    for i, num in enumerate(nums):
        # Calculate the complement of the current number
        complement = target - num
        
        # Check if the complement is already in the dictionary
        if complement in complement_dict:
            # Return the indices of the two numbers that add up to the target
            return [complement_dict[complement], i]
        
        # Add the current number and its index to the dictionary
        complement_dict[num] = i
    
    # If no solution is found, return an empty list
    return []


def twoSums

# %%
def groupAnagrams(strs):
    """
    :type strs: List[str]
    :rtype: List[List[str]]
    """
    # Create a dictionary to store the anagrams
    anagrams = {}  #
    
    # Iterate through the list of strings
    for s in strs:
        # Sort the characters in the string
        sorted_s = ''.join(sorted(s))
        
        # Add the sorted string to the dictionary
        if sorted_s in anagrams:
            anagrams[sorted_s].append(s)
        else:
            anagrams[sorted_s] = [s]
    
    # Return the values of the dictionary as a list of lists
    return list(anagrams.values())

# %%
def topKFrequent(self, nums, k):    
    # Create a dictionary to store the frequency of each number
    frequency = {}
    
    # Iterate through the list of numbers and count the frequency of each number
    for num in nums:
        if num in frequency:
            frequency[num] += 1
        else:
            frequency[num] = 1
    
    # Sort the dictionary by value in descending order
    sorted_frequency = sorted(frequency.items(), key=lambda x: x[1], reverse=True)
    
    # Return the first k elements from the sorted list
    return [x[0] for x in sorted_frequency[:k]]

# %% [markdown]
# Palindrome

# %%
def isPalindrome(s):
    # Remove non-alphanumeric characters and convert to lowercase
    s = ''.join(c.lower() for c in s if c.isalnum())
    
    # Compare the string with its reverse
def isPalindrome(s):
    # Remove non-alphanumeric characters and convert to lowercase
    s = ''.join(c.lower() for c in s if c.isalnum())
    
    # Iterate through the string from both ends
    for i in range(len(s)//2):
        # Compare the characters at the corresponding positions
        if s[i] != s[len(s)-i-1]:
            return False
    
    return True
    return s == s[::-1]


def isPalindrome(s):
    # Remove non-alphanumeric characters and convert to lowercase
    s = ''.join(c.lower() for c in s if c.isalnum())
    
    # Compare the string with its reverse
    return s == s[::-1]

def isPalindrome(s):
    newStr = ""

    for c in s:
        if c.isalnum():
            newStr += c.lower()
    return newStr == newStr[::-1]




def isPalindrome(self, x):
    """
    :type x: int
    :rtype: bool
    """
    if x < 0:
        return False
    string_x = str(x)
        
    for i in range(len(string_x)//2):
        if string_x[i] != string_x[-i-1]:
            return False
    return True
    

def isPalindrome(self, x):
    l = 0
    r = len(x) - 1

    while l < r:
        while l < r and not self.is_alphanumeric(x[l]):
            l += 1
        while l < r and not self.is_alphanumeric(x[r]):
            r -= 1
        if x[l].lower() != x[r].lower():
            return False
        l += 1
        r -= 1
    return True    

def is_alphanumeric(c):
    return ((ord('A') <= ord(c) <= ord('Z')) or (ord('a') <= ord(c) <= ord('z')) or (ord('0') <= ord(c) <= ord('9')))


is_alpha = ('A' <= c <= 'Z') or ('a' <= c <= 'z')
    is_digit = ('0' <= c <= '9')
    return is_alpha or is_digit

# %%
def twoSum(nums, target):
    l,r = 0, len(nums) - 1
    while l < r:
        if nums[l] + nums[r] == target:
            return [l+1, r+1]
        elif nums[l] + nums[r] < target:
            l += 1
        else:
            r -= 1
    return []

# %% [markdown]
# 9

# %%
def theeeSum(nums):
    nums.sort()
    res = []
    for i in range(len(nums)-2):
        if i > 0 and nums[i] == nums[i-1]:
            continue
        l, r = i+1, len(nums)-1
        while l < r:
            s = nums[i] + nums[l] + nums[r]
            if s < 0:
                l += 1
            elif s > 0:
                r -= 1
            else:
                res.append([nums[i], nums[l], nums[r]])
                while l < r and nums[l] == nums[l+1]:
                    l += 1
                while l < r and nums[r] == nums[r-1]:
                    r -= 1
                l += 1
                r -= 1
    return res  


def threeSum(self, nums):
    nums.sort()
    res = []
    for i, a in enumerate(nums):
        if i > 0 and a == nums[i-1]:
            continue
        l, r = i+1, len(nums)-1
        while l < r:
            three_sum = a + nums[l] + nums[r]
            if three_sum < 0:
                l += 1
            elif three_sum > 0:
                r -= 1
            else:
                res.append([a, nums[l], nums[r]])
                while l < r and nums[l] == nums[l+1]:
                    l += 1
                while l < r and nums[r] == nums[r-1]:
                    r -= 1
                l += 1
                r -= 1

# %%
def maxHieght(self, hieght):
    max_area = 0
    l, r = 0, len(hieght) - 1
    while l < r:
        max_area = max(max_area, min(hieght[l], hieght[r]) * (r - l))
        if hieght[l] < hieght[r]:
            l += 1
        else:
            r -= 1
    return max_area


def maxArea(self, height):
    #brute force
    res = 0

    for l in range(len(height)):
        for r in range(l+1, len(height)):
            res = max(res, min(height[l], height[r]) * (r-l))
    return res

# %%
def validParentheses(s):
    stack = []

    mapping = {")": "(", "}": "{", "]": "["}
    for char in s:
        if char in mapping:
            top_element = stack.pop() if stack else '#'
            if mapping[char] != top_element:
                return False
        else:
            stack.append(char)
    return not stack

# %%
class MinStack(object):

    def __init__(self):
        self.stack = []
        self.min_stack = []

    def push(self, val):
        """
        :type val: int
        :rtype: None
        """
        self.stack.append(val)
        # If the min stack is empty or the value is less than or 
        # equal to the top of the min stack, add it to the min stack
        if not self.min_stack or val <= self.min_stack[-1]:
            self.min_stack.append(val)
        
        

    def pop(self):
        """
        :rtype: None
        """
        val = self.stack.pop()
        if self.stack.pop() == self.min_stack[-1]:
            self.min_stack.pop()



    def top(self):
        """
        :rtype: int
        """
        # Return the top element of the stack
        # without removing it
        
        return self.stack[-1]
    
        

    def getMin(self):
        """
        :rtype: int
        """
        return self.min_stack[-1]

# %%
class MinStack(object):

    def __init__(self):
        self.stack = []
        self.min_stack = []

    def push(self, val):
        """
        :type val: int
        :rtype: None
        """
        self.stack.append(val)

        if not self.min_stack or val <= self.min_stack[-1]:
            self.min_stack.append(val)
       

    def pop(self):
        """
        :rtype: None
        """
        val = self.stack.pop()  # Call the pop method to actually pop the top element
        if val == self.min_stack[-1]:
            self.min_stack.pop()
        

    def top(self):
        """
        :rtype: int
        """
        return self.stack[-1]
        

    def getMin(self):
        """
        :rtype: int
        """
        return self.min_stack[-1]

# %%
def evalRPN(self, tokens):
        """
        :type tokens: List[str]
        :rtype: int
        """
        stack = []
        for token in tokens:
            if token not in "+-*/":
                stack.append(int(token))
            else:
                b = stack.pop()
                a = stack.pop()
                if token == "+":
                    stack.append(a+b)
                elif token == "-":
                    stack.append(a-b)
                elif token == "*":
                    stack.append(a*b)
                else:
                    stack.append(int(float(a)/b))
        return stack.pop()

# %% [markdown]
# Binary Search of an int.

# %%
def search(nums, target):
    l, r = 0, len(nums) - 1
    while l <= r:
        mid = l + (r - l) // 2
        if nums[mid] == target:
            return mid
        if nums[l] <= nums[mid]:
            if nums[l] <= target <= nums[mid]:
                r = mid - 1
            else:
                l = mid + 1
        else:
            if nums[mid] <= target <= nums[r]:
                l = mid + 1
            else:
                r = mid - 1
    return -1

# Test the function
nums = [-1,0,3,5,9,12]
target = -1
print(search(nums, target))
# Out:
# 0

# %%
def search2dMatrix(matrix, target):
    if not matrix:
        return False
    ROWS, COLS = len(matrix), len(matrix[0])
    top, bot = 0, ROWS*COLS-1
    while top <= bot:
        mid = top + (bot-top) // 2
        mid_element = matrix[mid//COLS][mid%ROWS]
        if mid_element == target:
            return True
        else:
            if mid_element < target:
                top = mid + 1
            else:
                bot = mid - 1
    return False

# Test the function
matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]]
target = 3
print(search2dMatrix(matrix, target))

print(search2dMatrix(matrix, 4))
# Out:
# True
# False

# %%
def search2dMatrix(matrix, target):
    if not matrix:
        return False
    ROWS, COLS = len(matrix), len(matrix[0])
    top, bot = 0, ROWS*COLS-1
    while top <= bot:
        row = (top + bot) // 2
        if target > matrix[row][-1]:
            top = row + 1
        elif target < matrix[row][0]:
            bot = row - 1
        else:
            break
    if not (top <= bot):
        return False
    row = (top + bot) // 2
    left, right = 0, COLS-1
    while left <= right:
        mid = (left + right) // 2
        if target == matrix[row][mid]:
            return True
        elif target > matrix[row][mid]:
            left = mid + 1
        else:
            right = mid - 1

# %%
def kokoEatingBananas(piles, h):
    def possible(k):
        # Initialize a total variable to keep track of the total hours needed
        total_hours_needed = 0
    
        # Iterate through each pile in the piles list
        for p in piles:
            # Calculate hours needed for the current pile
            # The formula (p-1)//k + 1 is used to ensure that even if there are leftovers
            # that don't make up a full 'k', they still count as an hour
            hours_for_current_pile = (p - 1) // k + 1
        
            # Add the hours needed for the current pile to the total
            total_hours_needed += hours_for_current_pile
    
        # After calculating the total hours needed for all piles, check if it's less than or equal to h
        is_possible = total_hours_needed <= h
    
        # Return the result of the check
        return is_possible
    l, r = 1, max(piles)
    while l < r:
        mid = l + (r - l) // 2
        if possible(mid):
            r = mid
        else:
            l = mid + 1
    return l

matrix = [3,6,7,11]
target = 8
print(kokoEatingBananas(matrix, target))
# Out:
# 4

# %%
def minEatingSpeed(piles, h):
    def possible(k):
        # Initialize a total variable to keep track of the total hours needed
        total_hours_needed = 0
    
        # Iterate through each pile in the piles list
        for p in piles:
            # Calculate hours needed for the current pile
            # The formula (p-1)//k + 1 is used to ensure that even if there are leftovers
            # that don't make up a full 'k', they still count as an hour
            hours_for_current_pile = (p - 1) // k + 1
        
            # Add the hours needed for the current pile to the total
            total_hours_needed += hours_for_current_pile
    
        # After calculating the total hours needed for all piles, check if it's less than or equal to h
        is_possible = total_hours_needed <= h
    
        # Return the result of the check
        return is_possible
    l, r = 1, max(piles)
    while l < r:
        mid = l + (r - l) // 2
        if possible(mid):
            r = mid
        else:
            l = mid + 1
    return l

# %%
def maxProfit(prices):
    if not prices:
        return 0
    max_profit = 0
    min_price = prices[0]
    for price in prices:
        if price < min_price:
            min_price = price
        max_profit = max(max_profit, price - min_price)
    return max_profit

# %%
def maxProfit(prices):
    if not prices:
        return 0
    max_profit = 0
    left = 0
    right = 1
    while right < len(prices):
        if prices[right] < prices[left]:
            left = right
        else:
            max_profit = max(max_profit, prices[right] - prices[left])
        right += 1
    return max_profit

# %%
def containsDuplicate(nums):
    num_set = set()
    for num in nums:
        if num in num_set:
            return True
        num_set.add(num)
    return False

# %%
def validAnagram(s, t):
    if len(s) != len(t):
        return False
    s_count = {}
    t_count = {}
    for i in range(len(s)):
        if s[i] in s_count:
            s_count[s[i]] += 1
        else:
            s_count[s[i]] = 1
        if t[i] in t_count:
            t_count[t[i]] += 1
        else:
            t_count[t[i]] = 1
    return s_count == t_count


def validAnagram(s, t):
    return sorted(s) == sorted(t)
def validAnagram(s, t):
    return collections.Counter(s) == collections.Counter(t)

# %%
def twoSum(nums, target):
    num_dict = {} # val: index
    for i, num in enumerate(nums):
        complement = target - num
        if complement in num_dict:
            return [num_dict[complement], i]
        num_dict[num] = i
    return []

# Test the function
nums = [2,7,11,15]
target = 9
print(twoSum(nums, target))
nums = [3,2,4]
target = 9
print(twoSum(nums, target))
# Out:
# [0, 1]
# []

# %%
#create a method let takes in a string and returns te longest substring without repeating characters
def lengthOfLongestSubstring(s):
    start = 0
    max_length = 0
    used_char = {}
    for i in range(len(s)):
        if s[i] in used_char and start <= used_char[s[i]]:
            start = used_char[s[i]] + 1
        else:
            max_length = max(max_length, i - start + 1)
        used_char[s[i]] = i
    return max_length

# %%
#create a method let takes in a string and returns te longest substring without repeating characters using a set
def lengthOfLongestSubstring(s):
    start = 0
    max_length = 0
    used_char = set()
    for i in range(len(s)):
        if s[i] in used_char:
            while s[i] in used_char:
                used_char.remove(s[start])
                start += 1
        used_char.add(s[i])
        max_length = max(max_length, i - start + 1)
    return max_length

# %%
def lengthofLongestSubstring(s):
    charSet = set()
    l = 0
    res = 0

    for r in range(len(s)):
        while s[r] in charSet:
            charSet.remove(s[l])
            l += 1
        charSet.add(s[r])
        res = max(res, r - l + 1)

# %%
#reverse a singly linked list
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
    def reverseList(head):
        prev = None
        current = head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        return prev

# %%
def reverseList(head):
    prev = None
    current = head
    while current:
        next_node = current.next
        current.next = prev
        prev = current
        current = next_node
    return prev

# %%
def addTwoNumbers(l1,l2):    
    dummy = ListNode(0)
    current = dummy
    carry = 0
    while l1 or l2 or carry:
        if l1:
            carry += l1.val
            l1 = l1.next
        if l2:
            carry += l2.val
            l2 = l2.next
        current.next = ListNode(carry % 10)
        current = current.next
        carry //= 10
    return dummy.next

# %%
def mergeTwoSortedList(l1,l2):
    dummy = ListNode(0)
    current = dummy
    while l1 and l2:
        if l1.val < l2.val:
            current.next = l1
            l1 = l1.next
        else:
            current.next = l2
            l2 = l2.next
        current = current.next
    current.next = l1 or l2
    return dummy.next

# %%
def reoderList(head):
    if not head or not head.next:
        return
    slow = fast = head
    #find the middle       
    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next
    prev, current = None, slow #reverse the second half 
    while current: ##curent is the second half of the listnode
        temp = current.next  # Temporarily store the next node
        # Move current.next to point to prev
        current.next = prev
        # Update prev to be the current node before moving on
        prev = current
        # Move to the next node in the original sequence
        current = temp

        current.next = prev
        prev = current
        current = current.next
    first, second = head, prev
    while second.next:
        first.next, first = second, first.next
        second.next, second = first, second.next

# %%
class Solution:
    def reorderList(self, head: ListNode) -> None:
        # find middle
        slow, fast = head, head.next
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next

        # reverse second half
        second = slow.next
        prev = slow.next = None
        while second:
            tmp = second.next
            second.next = prev
            prev = second
            second = tmp

        # merge two halfs
        first, second = head, prev
        while second:
            tmp1, tmp2 = first.next, second.next
            first.next = second
            second.next = tmp1
            first, second = tmp1, tmp2

# %%
def hasCycle(head):
    slow = fast = head
    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next
        if slow == fast:
            return True
    return False

# %%
def productExceptSelf(nums):
    n = len(nums)
    result = [1] * n
    left = 1
    for i in range(1, n):
        left *= nums[i-1]
        result[i] *= left
    right = 1
    for i in range(n-2, -1, -1):
        right *= nums[i+1]
        result[i] *= right
    return result

# %%
def productExceptSelf(self, nums):
        """
        :type nums: List[int]
        :rtype: List[int]
        """
        total = sum(nums)
        min = total - nums[0]
        

        for i in range(1, len(nums)):
            if total - nums[i] < min:
                min = total - nums[i]
                nums[i] = min
        return nums

# %%
def productExceptSelf(nums):
    n = len(nums)
    result = [1] * n
    prefix_product = 1
    suffix_product = 1

    # Calculate prefix product
    for i in range(n):
        result[i] *= prefix_product
        prefix_product *= nums[i]

    # Calculate suffix product
    for i in range(n - 1, -1, -1):
        result[i] *= suffix_product
        suffix_product *= nums[i]

    return result

# Test the function
nums = [1, 2, 3, 4]
print(productExceptSelf(nums))

nums = [-1, 1, 0, -3, 3]
print(productExceptSelf(nums))

# %%
def productExceptSelf(nums):
    res = [1] * len(nums)
    prefix = 1
    for i in range(len(nums)):
        res[i] = prefix
        prefix *= nums[i]
    postfix = 1
    for i in range(len(nums)-1, -1, -1):
        res[i] *= postfix
        postfix *= nums[i]
    return res

# %%
def maxSubArray(nums):
    max_sum = nums[0]
    current_sum = nums[0]
    for num in nums[1:]:
        current_sum = max(num, current_sum + num) #if current_sum is negative it will always pick num
        max_sum = max(max_sum, current_sum)
    return max_sum

# %%
def maxSubArray(nums):
    max_sum = nums[0]
    current_sum = 0
    for num in nums[1:]: #start from the second element, since we already have the first element saves as max_sum, skips the first element
        current_sum = max(num, current_sum + num)
        max_sum = max(max_sum, current_sum)
    return max_sum

# %%
def maxSubArray(nums):
    max_sum = nums[0]
    cur_sum = 0

    for n in nums:
        if cur_sum < 0:
            cur_sum = 0
        cur_sum += n
        max_sum = max(max_sum, cur_sum)
    return max_sum

# %%
def maxProduct(nums):
    max_product = nums[0]
    current_max = nums[0]
    current_min = nums[0]
    for num in nums[1:]:
        temp = current_max
        current_max = max(num, current_max * num, current_min * num)
        current_min = min(num, temp * num, current_min * num)
        max_product = max(max_product, current_max)
    return max_product

def maxProduct(nums):
    res = max(nums)
    curMax = curMin = 1

    for num in nums:
        if num < 0:
            curMax, curMin = curMin, curMax
        curMax = max(num, curMax * num)
        curMin = min(num, curMin * num)
        res = max(res, curMax)

# %%
#find min on a list of nums that has been rotated using log n
def findMin(nums):
    l, r = 0, len(nums) - 1
    while l < r:
        mid = l + (r - l) // 2
        if nums[mid] < nums[r]:
            r = mid
        else:
            l = mid + 1
    return nums[l]

# %%
#search in a rotated sorted array tp see of the number exist and return its index
def search(nums, target):
    l, r = 0, len(nums) - 1
    while l <= r:
        mid = l + (r - l) // 2
        if nums[mid] == target:
            return mid
        if nums[l] <= nums[mid]:
            if nums[l] <= target <= nums[mid]:
                r = mid - 1
            else:
                l = mid + 1
        else:
            if nums[mid] <= target <= nums[r]:
                l = mid + 1
            else:
                r = mid - 1
    return -1

# %%
def hammngWeight(n):
    count = 0
    while n:
        n &= n - 1
        count += 1
    return count

#test the function
n = 0b1011
print(hammngWeight(n))
# Out:
# 3

# %%
def climbStairs(n):
    one, two = 1,1
    for i in range(n-1):
        temp = one
        first = one + two
        second = temp
    return second
